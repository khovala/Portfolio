# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Сергей! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты и сразу увидеть исправленное. <br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что у нас получилось!</b></font>

# %% [markdown]
# # Описание проекта
#
# Вы аналитик компании «Мегалайн» — федерального оператора сотовой связи. Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег.
# Вам предстоит сделать предварительный анализ тарифов на небольшой выборке клиентов. В вашем распоряжении данные 500 пользователей «Мегалайна»: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.
# Описание тарифов
# Тариф «Смарт»
# 1.	Ежемесячная плата: 550 рублей
# 2.	Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
# 3.	Стоимость услуг сверх тарифного пакета:
# o	минута разговора: 3 рубля
# o	сообщение: 3 рубля
# o	1 Гб интернет-трафика: 200 рублей
# Тариф «Ультра»
# 1.	Ежемесячная плата: 1950 рублей
# 2.	Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
# 3.	Стоимость услуг сверх тарифного пакета:
# o	минута разговора: 1 рубль
# o	сообщение: 1 рубль
# o	1 Гб интернет-трафика: 150 рублей
#
# ПЛАН ИССЛЕДОВАНИЯ
# Шаг 1. Откроем и изучим датасеты
# Шаг 2. Подготовим данные
# •	Приведем данные к нужным типам;
# •	Найдем и исправим ошибки в данных, если они есть.
# Посчитаем для каждого пользователя:
# •	количество сделанных звонков и израсходованных минут разговора по месяцам;
# •	количество отправленных сообщений по месяцам;
# •	объем израсходованного интернет-трафика по месяцам;
# •	помесячную выручку с каждого пользователя
# Шаг 3. Проанализируем данные
# Опишем поведение клиентов оператора, исходя из выборки. Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц? Посчитаем среднее количество, дисперсию и стандартное отклонение. Постройте гистограммы. Опишите распределения.
# Шаг 4. Проверим гипотезы
# •	средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются;
# •	средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.
# Шаг 5. Напишем общий вывод

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Желательно подробнее давать описание проекта с указанием ключевых данных (описания тарифов, условия тарификации и т.д.). Описание может содержать краткий план исследования. 😲</font>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
try:
    data_calls= pd.read_csv(r"C:\Users\Пользователь\Documents\Data Analyst\СПРИНТ 5\calls.csv")
    data_internet= pd.read_csv(r"C:\Users\Пользователь\Documents\Data Analyst\СПРИНТ 5\internet.csv")
    data_messages= pd.read_csv(r"C:\Users\Пользователь\Documents\Data Analyst\СПРИНТ 5\messages.csv")
    data_tariffs= pd.read_csv(r"C:\Users\Пользователь\Documents\Data Analyst\СПРИНТ 5\tariffs.csv")
    data_users= pd.read_csv(r"C:\Users\Пользователь\Documents\Data Analyst\СПРИНТ 5\users.csv")
except:
    data_calls = pd.read_csv("/datasets/calls.csv")
    data_internet = pd.read_csv("/datasets/internet.csv")
    data_messages = pd.read_csv("/datasets/messages.csv")
    data_tariffs = pd.read_csv("/datasets/tariffs.csv")
    data_users = pd.read_csv("/datasets/users.csv")
data_calls.info()
display(data_calls.head(10))
print(data_calls.columns)
data_internet.info()
display(data_internet.head(10))
print(data_internet.columns)
data_messages.info()
display(data_messages.head(10))
print(data_messages.columns)
data_tariffs.info()
display(data_tariffs.head(10))
print(data_messages.columns)
data_users.info()
display(data_users.head(10))
print(data_users.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000
# 5  1000_5  2018-11-02      0.00     1000
# 6  1000_6  2018-10-18      0.00     1000
# 7  1000_7  2018-08-22     18.31     1000
# 8  1000_8  2018-09-15     18.44     1000
# 9  1000_9  2018-08-15      0.00     1000
# Index(['id', 'call_date', 'duration', 'user_id'], dtype='object')
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Лучше разделять по разным ячейкам загрузку библиотек и датасета. 🙄</font>

# %% [markdown]
# ## Обзор данных.
# Прочитали файлы, вывели информацию о таблицах. Увидели недостатки датафреймов: Несоответствие типов данных, различное количество данных в таблицах.

# %%
data_calls['call_date'] = pd.to_datetime(data_calls['call_date'], format='%Y-%m-%d') # переведем столбец из типа object в datetime
data_calls['month'] = pd.DatetimeIndex(data_calls['call_date']).month # выделим из даты только месяц, сформировав новый столбец
print(data_calls['month'].unique()) # в новом столбце проверим все уникальные значения
data_calls.info()
display(data_calls.head(10))
# Out:
# [ 7  8  6  9 12 11 10  5  3  4  1  2]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  datetime64[ns]
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
#  4   month      202607 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 7.7+ MB
#        id  call_date  duration  user_id  month
# 0  1000_0 2018-07-25      0.00     1000      7
# 1  1000_1 2018-08-17      0.00     1000      8
# 2  1000_2 2018-06-11      2.85     1000      6
# 3  1000_3 2018-09-21     13.80     1000      9
# 4  1000_4 2018-12-15      5.18     1000     12
# 5  1000_5 2018-11-02      0.00     1000     11
# 6  1000_6 2018-10-18      0.00     1000     10
# 7  1000_7 2018-08-22     18.31     1000      8
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, перевели даты в нужный формат и добавили колонку с категорией месяца.</font><br>
# <font color='DarkMagenta'>👉 Было бы правильно проверить на дубликаты, если мы это сделали и потом удалили код, то это не правильно.</font>

# %%
data_calls['duration']=np.ceil(data_calls['duration']) # согласно условиям тарифов, звоки тарифицируются поминутно и округляются в большую сторону
display(data_calls.head(10))
# Out:
#        id  call_date  duration  user_id  month
# 0  1000_0 2018-07-25       0.0     1000      7
# 1  1000_1 2018-08-17       0.0     1000      8
# 2  1000_2 2018-06-11       3.0     1000      6
# 3  1000_3 2018-09-21      14.0     1000      9
# 4  1000_4 2018-12-15       6.0     1000     12
# 5  1000_5 2018-11-02       0.0     1000     11
# 6  1000_6 2018-10-18       0.0     1000     10
# 7  1000_7 2018-08-22      19.0     1000      8
# 8  1000_8 2018-09-15      19.0     1000      9
# 9  1000_9 2018-08-15       0.0     1000      8

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что для округления используется np.ceil, так как он работает сразу со всем столбцом. 👍</font>

# %% [markdown]
# ## Предобработка данных
#
# На предыдущем этапе сформировали новый датафрейм с колонкой месяц и округлили время звонков до минут в большую сторону.
# Следующим шагом сгруппируем данные по uset_id и month для того,чтобы посчитать сколько времени в каком месяце каждый абонент тратил на звонки.

# %%
data_calls_grouped = data_calls.groupby(['user_id', 'month']).agg({'id':'count', 'duration':'sum'}).reset_index()

display(data_calls_grouped.head(10))
# Out:
#    user_id  month  id  duration
# 0     1000      5  22     159.0
# 1     1000      6  43     172.0
# 2     1000      7  47     340.0
# 3     1000      8  52     408.0
# 4     1000      9  58     466.0
# 5     1000     10  57     350.0
# 6     1000     11  43     338.0
# 7     1000     12  46     333.0
# 8     1001     11  59     430.0
# 9     1001     12  63     414.0

# %% [markdown]
# Мы сгруппировали данные по пользователям и месяцам, посчитали количество звонков в месяц и их продолжительность в минутах по каждому абоненту.

# %%
data_calls_grouped_nan=data_calls_grouped.isna().sum() #проверим напропуски и дупликаты
data_calls_grouped=data_calls_grouped.drop_duplicates()
data_calls_grouped_nan
data_calls_grouped
# Out:
#       user_id  month  id  duration
# 0        1000      5  22     159.0
# 1        1000      6  43     172.0
# 2        1000      7  47     340.0
# 3        1000      8  52     408.0
# 4        1000      9  58     466.0
# ...       ...    ...  ..       ...
# 3169     1498     10  41     247.0
# 3170     1499      9   9      70.0
# 3171     1499     10  68     449.0
# 3172     1499     11  74     612.0
# 3173     1499     12  69     492.0
#
# [3174 rows x 4 columns]

# %%
data_internet['session_date'] = pd.to_datetime(data_internet['session_date'], format='%Y-%m-%d') # переведем столбец из типа object в datetime
data_internet['month'] = pd.DatetimeIndex(data_internet['session_date']).month
data_internet_grouped = data_internet.groupby(['user_id', 'month']).agg({'id':'count', 'mb_used':'sum'}).reset_index()
data_internet_grouped['mb_used']=np.ceil(data_internet_grouped['mb_used']/1024)

data_internet_grouped_nan=data_internet_grouped.isna().sum() #проверим напропуски и дупликаты
data_internet_grouped=data_internet_grouped.drop_duplicates()
data_internet_grouped_nan
data_internet_grouped
# Out:
#       user_id  month  id  mb_used
# 0        1000      5   5      3.0
# 1        1000      6  49     23.0
# 2        1000      7  29     14.0
# 3        1000      8  29     14.0
# 4        1000      9  27     15.0
# ...       ...    ...  ..      ...
# 3198     1498     10  59     21.0
# 3199     1499      9   5      2.0
# 3200     1499     10  58     18.0
# 3201     1499     11  49     18.0
# 3202     1499     12  45     13.0
#
# [3203 rows x 4 columns]

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Было бы правильно сделать анализ аномалий в датасете по интернет-трафику, лучше их визуализировать гистограммой. Проанализировать их причину и принять решение по обработке.</font><br>
# <font color='DarkGreen'>👌 Хорошо, не забыли округлить трафик до гигабайтов. 👍</font>

# %% [markdown]
# Проделали то же самое с таблицей data_internet. Получили датасет сгруппированный по юзерам, месяцам и с количеством потребленного интернета, округленного до гб. Убрали явные дубликаты и проверили на пропуски.

# %%
data_messages['message_date'] = pd.to_datetime(data_messages['message_date'], format='%Y-%m-%d') # переведем столбец из типа object в datetime
data_messages['id']=data_messages['id'].astype('int64')
data_messages['month'] = pd.DatetimeIndex(data_messages['message_date']).month
data_messages_grouped = data_messages.groupby(['user_id', 'month']).agg({'id':'count'}).reset_index()

data_messages_grouped_nan=data_messages_grouped.isna().sum() #проверим на пропуски и дупликаты
data_messages_grouped=data_messages_grouped.drop_duplicates()
data_messages_grouped_nan
data_messages_grouped
# Out:
#       user_id  month  id
# 0        1000      5  22
# 1        1000      6  60
# 2        1000      7  75
# 3        1000      8  81
# 4        1000      9  57
# ...       ...    ...  ..
# 2712     1498     10  42
# 2713     1499      9  11
# 2714     1499     10  48
# 2715     1499     11  59
# 2716     1499     12  66
#
# [2717 rows x 3 columns]

# %%
data_users['reg_date']=pd.to_datetime(data_users['reg_date'], format='%Y-%m-%d')
data_users['churn_date']=pd.to_datetime(data_users['churn_date'], format='%Y-%m-%d')
data_users.rename(columns={'tariff':'tariff_name'}, inplace=True) #поменяем название колонки с тарифом, для того чтобы потом можно было
data_users=data_users.drop_duplicates()                           # объединить этот датафрейм с другими
data_users_nan=data_users.isna().sum()
print(data_users_nan)
display(data_users)
# Out:
# user_id          0
# age              0
# churn_date     462
# city             0
# first_name       0
# last_name        0
# reg_date         0
# tariff_name      0
# dtype: int64
#      user_id  age churn_date         city first_name  last_name   reg_date  \
# 0       1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1       1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2       1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3       1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4       1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
# ..       ...  ...        ...          ...        ...        ...        ...
# 495     1495   65        NaT      Иркутск  Авксентий      Фокин 2018-08-28
# 496     1496   36        NaT      Вологда     Трифон     Блохин 2018-01-27
# 497     1497   32        NaT    Челябинск   Каролина     Агеева 2018-10-09
# ...

# %%
data_total= data_calls_grouped.merge(data_internet_grouped, on=['user_id', 'month'], how='outer') #объединим все таблицы в одну с помощью merge
data_total= data_total.merge(data_messages_grouped, on=['user_id', 'month'], how='outer')
data_total= data_total.merge(data_users, on='user_id', how='outer')
data_total= data_total.merge(data_tariffs, on= 'tariff_name', how= 'inner')
data_total.info()
display(data_total.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3216 entries, 0 to 3215
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                3216 non-null   int64
#  1   month                  3214 non-null   float64
#  2   id_x                   3174 non-null   float64
#  3   duration               3174 non-null   float64
#  4   id_y                   3203 non-null   float64
#  5   mb_used                3203 non-null   float64
#  6   id                     2717 non-null   float64
#  7   age                    3216 non-null   int64
#  8   churn_date             189 non-null    datetime64[ns]
#  9   city                   3216 non-null   object
#  10  first_name             3216 non-null   object
#  11  last_name              3216 non-null   object
#  12  reg_date               3216 non-null   datetime64[ns]
#  13  tariff_name            3216 non-null   object
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Надо проанализировать куда у нас пропало два пользователя после объединения таблиц, см. код ниже. Вот только не надо их сразу включать в сводную таблицу и считать на них выручку. Надо по ним принять правильное решение. </font>
# Комментарий студента: нашел пропажу. Поменял inner на outer в строке: data_total= data_total.merge(data_users, on='user_id', how='outer')

# %%
# Комментарий ревьюера
data_total.user_id.unique().shape
# Out:
# (500,)

# %%
# поменяем назвния столбцов для наглядности
data_total.rename(columns={'id_x':'calls', 'id_y':'internet_sessions', 'id':'messages', 'mb_used':'gb_used'}, inplace=True)
# заменим пропуски в столбцее messages на 0, тк. это значит,что скорее всего данной услугой не пользовались
data_total['messages']=data_total['messages'].fillna(0) 
data_total['calls']=data_total['calls'].fillna(0) 
data_total['internet_sessions']=data_total['internet_sessions'].fillna(0) 
data_total['duration']=data_total['duration'].fillna(0)
data_total['gb_used']=data_total['gb_used'].fillna(0) 



# в некоторых столбцах поменяем формат
data_total['month']=data_total['month'].astype('Int64')
data_total['calls']=data_total['calls'].astype('Int64')
data_total['internet_sessions']=data_total['internet_sessions'].astype('Int64')
data_total['gb_used']=data_total['gb_used'].astype('Int64')
data_total['messages']=data_total['messages'].astype('Int64')
display(data_total.head(10))
data_total.info()
# Out:
#    user_id  month  calls  duration  internet_sessions  gb_used  messages  age  \
# 0     1000      5     22     159.0                  5        3        22   52
# 1     1000      6     43     172.0                 49       23        60   52
# 2     1000      7     47     340.0                 29       14        75   52
# 3     1000      8     52     408.0                 29       14        81   52
# 4     1000      9     58     466.0                 27       15        57   52
# 5     1000     10     57     350.0                 27       15        73   52
# 6     1000     11     43     338.0                 24       15        58   52
# 7     1000     12     46     333.0                 21       10        70   52
# 8     1003      8     55     380.0                 15        9        37   23
# 9     1003      9    134     961.0                 22       13        91   23
#
#   churn_date       city  ...  last_name   reg_date tariff_name  \
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что заполнили пропуски нулями. 👍</font>

# %%
# Посчитаем выручку с каждого абонента за каждый месяц.

def extra_cost (row):
    cost_sum=0
    cost1=row['duration']
    cost2=row['gb_used']
    cost3=row['messages']
    cost4=row['minutes_included']
    cost5=row['mb_per_month_included']/1024
    cost6=row['messages_included']
    cost7=row['rub_per_minute']
    cost8=row['rub_per_gb']
    cost9=row['rub_per_message']
    if cost1 > cost4:
        cost_sum += ((cost1-cost4)*cost7)
    if cost2 > cost5:
        cost_sum += ((cost2-cost5)*cost8)
    if cost3 > cost6:
        cost_sum += ((cost3-cost6)*cost9)
    return cost_sum
data_total['cost_per_month']=data_total.apply(extra_cost, axis=1) + data_total['rub_monthly_fee']
display(data_total.head(10))
display(data_total.tail(10))
# Out:
#    user_id  month  calls  duration  internet_sessions  gb_used  messages  age  \
# 0     1000      5     22     159.0                  5        3        22   52
# 1     1000      6     43     172.0                 49       23        60   52
# 2     1000      7     47     340.0                 29       14        75   52
# 3     1000      8     52     408.0                 29       14        81   52
# 4     1000      9     58     466.0                 27       15        57   52
# 5     1000     10     57     350.0                 27       15        73   52
# 6     1000     11     43     338.0                 24       15        58   52
# 7     1000     12     46     333.0                 21       10        70   52
# 8     1003      8     55     380.0                 15        9        37   23
# 9     1003      9    134     961.0                 22       13        91   23
#
#   churn_date       city  ...   reg_date tariff_name messages_included  \
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо! Прописали расчет выручки.</font>

# %% [markdown]
# ## Этап 2. Изучим поведение пользователей тарифов smart и ultra.

# %%
data_ultra= data_total[data_total['tariff_name'] == 'ultra'] #сделаем 2 отдельных датасета для тарифов ultra и smart
display(data_ultra.head(10))
data_ultra.info()
data_ultra.user_id.unique().shape

data_smart= data_total[data_total['tariff_name'] == 'smart'] 
display(data_smart.head(10))
data_smart.info()    
data_smart.user_id.unique().shape

#display(data_smart_mean_calls.head(10))
# Out:
#    user_id  month  calls  duration  internet_sessions  gb_used  messages  age  \
# 0     1000      5     22     159.0                  5        3        22   52
# 1     1000      6     43     172.0                 49       23        60   52
# 2     1000      7     47     340.0                 29       14        75   52
# 3     1000      8     52     408.0                 29       14        81   52
# 4     1000      9     58     466.0                 27       15        57   52
# 5     1000     10     57     350.0                 27       15        73   52
# 6     1000     11     43     338.0                 24       15        58   52
# 7     1000     12     46     333.0                 21       10        70   52
# 8     1003      8     55     380.0                 15        9        37   23
# 9     1003      9    134     961.0                 22       13        91   23
#
#   churn_date       city  ...   reg_date tariff_name messages_included  \
# ...

# %%
# изучим средние значения продолжительности звонков абонентов тарифа ultra
data_ultra_mean_calls=data_ultra['duration'].describe()
print(data_ultra_mean_calls)

pd.set_option('display.float_format', lambda x: '%.0f' % x)

#data_ultra.plot(kind='hist', y='duration',
               #bins=100, linewidth=3, alpha=0.5, figsize=(12,4), label='ultra_duration', grid=True, legend=True);
plt.hist([data_ultra['duration'], data_smart['duration']],bins=100, linewidth=3, alpha=0.5,
         label=['ultra_duration', 'smart_duration']) 
plt.legend(loc='upper right')
plt.xlabel('кол-во минут')

ultra_calls_var=np.var(data_ultra['duration'], ddof=1)
ultra_calls_std=np.sqrt(ultra_calls_var)
print('Дисперсия продолжительности звонков в Ultra = ',ultra_calls_var)
print('Стандартное отклонение продолжительности звонков в Ultra = ', ultra_calls_std)
print ('Не пользуются услугой -',data_ultra[data_ultra['duration'] ==0]['user_id'].count(), 'абонентов')
# Out:
# count     986.000000
# mean      526.089249
# std       317.887549
# min         0.000000
# 25%       282.500000
# 50%       518.000000
# 75%       751.750000
# max      1673.000000
# Name: duration, dtype: float64
# Дисперсия продолжительности звонков в Ultra =  101052.49354928387
# Стандартное отклонение продолжительности звонков в Ultra =  317.8875485911392
# Не пользуются услугой - 39 абонентов

# %%
data_smart_mean_calls=data_smart['duration'].describe()
print(data_smart_mean_calls)

plt.hist([data_ultra['duration'], data_smart['duration']],bins=100, linewidth=3, alpha=0.5,
         label=['ultra_duration', 'smart_duration']) 
plt.legend(loc='upper right')              

plt.xlabel('кол-во минут')
smart_calls_var=np.var(data_smart['duration'], ddof=1)
smart_calls_std=np.sqrt(smart_calls_var)
print('Дисперсия продолжительности звонков в Smart = ', smart_calls_var)
print('Стандартное отклонение продолжительности звонков в Smart = ', smart_calls_std)
print ('Не пользуются услугой -',data_smart[data_smart['duration'] ==0]['user_id'].count(), 'абонентов')
# Out:
# count   2230
# mean     418
# std      190
# min        0
# 25%      282
# 50%      422
# 75%      545
# max     1435
# Name: duration, dtype: float64
# Дисперсия продолжительности звонков в Smart =  36281.39383644458
# Стандартное отклонение продолжительности звонков в Smart =  190.4767540579285
# Не пользуются услугой - 9 абонентов

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 При проведении сравнительного анализа лучше на графики выводить данные обоих тарифов в одной координатной сетке с указанием меток тарифов. Сделаем?</font>

# %% [markdown]
# Вывод: мы видим нормальное распределение по обоим тарифам. Абоненты Ultra в среднем используют 527 минут из лимита тарифа в 3000 минут. Максимальное значение - 1673 минуты, что также почти вдвое меньше предоставенного лимита. В Smart Третий перцентиль имеет значение 545, которое превышает лимит в 500 минут, что говорит о том что больше четверти абонентов превышают установленный лимит. Абоненты Smart в среднем разговаривают по 418 минут из лимита в 500 минут.Максимальная длительность 1435 минут, что почти в 3 раза превышает лимит.
# Интересно отметить, что значительное количество абонентов (38 чел из выборки) в тарифе ультра не пользуются голосовой связью, в то время как в Smart таких абонентов всего 8. Продолжительность разговоров 0 минут.

# %%
# изучим смс-сообщения тарифа Ultra
data_ultra_mean_messages=data_ultra['messages'].describe()
print(data_ultra_mean_messages)
plt.hist([data_ultra['messages'], data_smart['messages']],
               bins=100, linewidth=3, alpha=0.5, label=['ultra_messages', 'smart_messages']);
plt.legend(loc='upper right')
plt.xlabel('кол-во sms') 

ultra_messages_var=np.var(data_ultra['messages'], ddof=1)
ultra_messages_std=np.sqrt(ultra_messages_var)
print('Дисперсия сообщений в Ultra = ', ultra_messages_var)
print('Стандартное отклонение сообщений в Ultra = ', ultra_messages_std)
print ('Не пользуются услугой -',data_ultra[data_ultra['messages'] ==0]['user_id'].count(), 'абонентов')
# Out:
# count   986
# mean     49
# std      48
# min       0
# 25%       6
# 50%      38
# 75%      79
# max     224
# Name: messages, dtype: float64
# Дисперсия сообщений в Ultra =  2285.4174246558414
# Стандартное отклонение сообщений в Ultra =  47.80603962530092
# Не пользуются услугой - 191 абонентов

# %%
# изучим смс-сообщения тарифа Smart
data_smart_mean_messages=data_smart['messages'].describe()
print(data_smart_mean_messages)
plt.hist([data_ultra['messages'], data_smart['messages']],
               bins=100, linewidth=3, alpha=0.5, label=['ultra_messages', 'smart_messages']);
plt.legend(loc='upper right')
plt.xlabel('кол-во sms') 

smart_messages_var=np.var(data_smart['messages'], ddof=1)
smart_messages_std=np.sqrt(smart_messages_var)
print('Дисперсия сообщений в Smart = ', smart_messages_var)
print('Стандартное отклонение сообщений в Smart = ', smart_messages_std)
print ('Не пользуются услугой -',data_smart[data_smart['messages'] ==0]['user_id'].count(), 'абонентов')
# Out:
# count   2230
# mean      33
# std       28
# min        0
# 25%       10
# 50%       28
# 75%       51
# max      143
# Name: messages, dtype: float64
# Дисперсия сообщений в Smart =  796.9552557301129
# Стандартное отклонение сообщений в Smart =  28.230395954185852
# Не пользуются услугой - 308 абонентов

# %% [markdown]
# Вывод по сообщениям:
# Большое количество абонентов обоих тарифов вообще не пользуются данной услугой вообще. В Ultra из лимита 1000 смс в среднем используют только 49, в Smart 33 из 50 лимита. Посмотрим на перцентили. В Смарт третий перцентиль имеет значение 51, что близко к значению лимита, это говорит о том,что почти четверть пользователей превышает лимит.В тарифе Ультра  дажем максимальное значение в 143 смс очень далеко от лимита в 1000 смс.

# %%
# изучим интернет трафик тарифа Ultra
data_ultra_mean_gb=data_ultra['gb_used'].describe()
print(data_ultra_mean_gb)
#data_ultra.plot(kind='hist', y='gb_used', 
               #bins=100, linewidth=3, alpha=0.5, figsize=(12,4), label='ultra_gb', grid=True, legend=True);
plt.hist(data_ultra['gb_used'],
               bins=100, linewidth=3, alpha=0.5, label='ultra_gb_used');
plt.hist(data_smart['gb_used'],
               bins=100, linewidth=3, alpha=0.5, label='smart_gb_used');

plt.legend(loc='upper right')
    
plt.xlabel('кол-во gb') 

ultra_gb_var=np.var(data_ultra['gb_used'], ddof=1)
ultra_gb_std=np.sqrt(ultra_gb_var)
print('Дисперсия интернет трафика в Ultra = ', ultra_gb_var)
print('Стандартное отклонение интернет трафика в Ultra = ', ultra_gb_std)
print ('Не пользуются услугой -',data_ultra[data_ultra['gb_used'] ==0]['user_id'].count(), 'абонентов')
# Out:
# count   986
# mean     19
# std      10
# min       0
# 25%      12
# 50%      19
# 75%      27
# max      49
# Name: gb_used, dtype: float64
# Дисперсия интернет трафика в Ultra =  97.37854429011234
# Стандартное отклонение интернет трафика в Ultra =  9.868056763624352
# Не пользуются услугой - 12 абонентов

# %%
# изучим интернет-трафик тарифа Smart
data_smart_mean_gb=data_smart['gb_used'].describe()
print(data_smart_mean_gb)
plt.hist(data_ultra['gb_used'],
               bins=100, linewidth=3, alpha=0.5, label='ultra_gb_used');
plt.hist(data_smart['gb_used'],
               bins=100, linewidth=3, alpha=0.5, label='smart_gb_used');

plt.legend(loc='upper right');
plt.xlabel('кол-во gb') 

smart_gb_var=np.var(data_smart['gb_used'], ddof=1)
smart_gb_std=np.sqrt(smart_gb_var)
print('Дисперсия интернет трафика в Smart = ', smart_gb_var)
print('Стандартное отклонение трафика в Smart = ', smart_gb_std)
print ('Не пользуются услугой -',data_smart[data_smart['gb_used'] ==0]['user_id'].count(), 'абонентов')
# Out:
# count   2230
# mean      16
# std        6
# min        0
# 25%       13
# 50%       17
# 75%       20
# max       38
# Name: gb_used, dtype: float64
# Дисперсия интернет трафика в Smart =  33.133453035506285
# Стандартное отклонение трафика в Smart =  5.7561665225657155
# Не пользуются услугой - 3 абонентов

# %% [markdown]
# Выводы по расходу интернет-трафика:
# У абонентов тарифа Ultra средний расход составляет 19 гб из предоставленных 30, третий персентиль находится на уровне 27, что говорит о том,что лимит превышают менее 25% пользователей. У Smart среднее значение 16, что больше лимита в 15 гб в рамках тарифа.Медианное значение в 17 говорит о том, что почти половина пользователей превышают лимит.

# %%
# проанализируем выручку с абонентов smart и ultra
data_smart_cost=data_smart['cost_per_month'].describe()
print(data_smart_cost)
plt.hist(data_ultra['cost_per_month'],
               bins=100, linewidth=3, alpha=0.5, label='ultra_выручка_с_абонента');
plt.hist(data_smart['cost_per_month'],
               bins=100, linewidth=3, alpha=0.5, label='smart_выручка_с_абонента');

plt.legend(loc='upper right');
plt.xlabel('выручка, руб.') 

smart_cost_var=np.var(data_smart['cost_per_month'], ddof=1)
smart_cost_std=np.sqrt(smart_cost_var)
print('Дисперсия выручки с абонента в Smart = ', smart_cost_var)
print('Стандартное отклонение выручки в Smart = ', smart_cost_std)
# Out:
# count   2230
# mean    1290
# std      818
# min      550
# 25%      550
# 50%     1021
# 75%     1750
# max     6770
# Name: cost_per_month, dtype: float64
# Дисперсия выручки с абонента в Smart =  669730.763894807
# Стандартное отклонение выручки в Smart =  818.370798534996

# %%
data_ultra_cost=data_ultra['cost_per_month'].describe()
print(data_ultra_cost)
plt.hist(data_ultra['cost_per_month'],
               bins=100, linewidth=3, alpha=0.5, label='ultra_выручка_с_абонента');
plt.hist(data_smart['cost_per_month'],
               bins=100, linewidth=3, alpha=0.5, label='smart_выручка_с_абонента');

plt.legend(loc='upper right');
plt.xlabel('выручка, руб.') 

ultra_cost_var=np.var(data_ultra['cost_per_month'], ddof=1)
ultra_cost_std=np.sqrt(ultra_cost_var)
print('Дисперсия выручки с абонента в Ultra = ', ultra_cost_var)
print('Стандартное отклонение выручки в Ultra = ', ultra_cost_std)
# Out:
# count    986
# mean    2070
# std      376
# min     1950
# 25%     1950
# 50%     1950
# 75%     1950
# max     4800
# Name: cost_per_month, dtype: float64
# Дисперсия выручки с абонента в Ultra =  141387.7148093615
# Стандартное отклонение выручки в Ultra =  376.0155778812382

# %%
# посчитаем суммарную выручку с абонентов тарифов smart и ultra по месяцам.
data_ultra_income= data_ultra.groupby('month')['cost_per_month'].sum()
data_smart_income= data_smart.groupby('month')['cost_per_month'].sum()
data_ultra_income
data_smart_income
plt.plot(data_ultra_income,
             linewidth=3, alpha=0.5, label='динамика выручки ultra');
plt.plot(data_smart_income,
             linewidth=3, alpha=0.5, label='динамика выручки smart')
plt.legend(loc='upper left');
plt.xlabel('выручка, руб.')
# Out:
# Text(0.5, 0, 'выручка, руб.')

# %% [markdown]
# Из анализа месячной выручки по тарифам мы наблюдаем следующее: до апреля выручка и динамика роста выручки у обоих тарифов примерно одинаковая.
# Однако, начиная с мая динамика роста выручки с абонентов тарифа Smart заметно ускоряется по сравнению с выручкой абонентов Ultra.
# Несмотря на более высокую абонентскую плату в Ultra, тариф Smart показывает лучшие результаты за счет превышения лимитов звонков,
# смс и траффика, а также за счет бОльшего количества абонентов (351 к 149)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Как инструкция на выполнение проекта, так и технические задания на проведение исследования не всегда содержат всю информацию, что необходимо сделать. Но указывается задача исследования, у нас это: "коммерческий департамент хочет понять, какой тариф приносит больше денег". Но мы ограничиваемся в анализе только количеством сообщений, длительностью звонков и интернет-трафиком. При этом у нас уже посчитано сколько пользователи платят за эти услуги, но сам анализ выручки в разрезе тарифа мы не делаем. Тогда, как мы получим ответ на вопрос какой тариф выгоднее?</font><br>
# <font color='Red'>🛠 Давай сделаем то же самое, но по выручке в разрезе тарифов. Хорошо?</font>

# %% [markdown]
# ## Шаг 5. Проверка гипотез
# •	средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются;
# •	средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.

# %%
#посчитаем среднюю выручку с абонента в месяц тарифа Ultra
cost_per_month_ultra_mean= data_ultra['cost_per_month'].mean()
print('Средняя выручка абонентов тарифа Ultra=',round(cost_per_month_ultra_mean,2))


# посчитаем среднюю выручку с абонента в месяц тарифа Smart
cost_per_month_smart_mean= data_smart['cost_per_month'].mean()
print('Средняя выручка абонентов тарифа Smart=',round(cost_per_month_smart_mean,2))
print('дельта составляет ', round(cost_per_month_ultra_mean-cost_per_month_smart_mean,2), 'или', round((cost_per_month_smart_mean/cost_per_month_ultra_mean*100),2), '%')
# Out:
# Средняя выручка абонентов тарифа Ultra= 2070.03
# Средняя выручка абонентов тарифа Smart= 1289.64
# дельта составляет  780.39 или 62.3 %

# %% [markdown]
# Сформулируем нулевую гипотезу: Средняя выручка пользователей тарифов Ultra и Smart равна.
# Альтернативная гипотеза: Средняя выручка пользователей тарифов Ultra и Smart НЕ равна. Мы можем просто сравнить рассчитанные средние значения, и визуально подтвердить или опровергнуть гипотезу. Но чтобы статистически это подтвердить, прибегнем к t-тесту.
#
# Проверим гипотезу т-тестом, определим значение pvalue, критический уровень статистической значимости определим в 0.05
# Если pvalue будет больше, чем хначение alpha, то гипотеза подтверждается. Если меньше, то гипотеза отвергется.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, правильно сформулированы гипотезы.</font>

# %%
sample_1=data_ultra['cost_per_month']
sample_2=data_smart['cost_per_month']
alpha=0.05 # коэффициент статистической значимости

results=st.ttest_ind(sample_1, sample_2, equal_var=False)
print ('p-значение=',results.pvalue)

if results.pvalue < alpha:
    display('Отвергаем нулевую гипотезу')
else:
    display('Не получилось отвергнуть нулевую гипотезу')

# %% [markdown]
# Проверим вторую гипотезу: • средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.
# Нулевая гипотеза (H0) будет сформулирована так: • средняя выручка пользователей из Москвы РАВНА выручке пользователей из других регионов.Альтернативная гипотеза (H1) будет звучать так: средняя выручка пользователей из Москвы ОТЛИЧАЕТСЯ от выручки пользователей из других регионов.

# %%
# рассчитаем средние значения выручек москвичей и абонентов в регионах
cost_moscow_mean= data_total[data_total['city']== 'Москва']['cost_per_month'].mean()
print ('Средняя выручка абонентов в Москве =', cost_moscow_mean)
cost_region_mean= data_total[data_total['city']!= 'Москва']['cost_per_month'].mean()
print ('Средняя выручка абонентов в регионах =', cost_region_mean)

# %%
sample_1=data_total[data_total['city']=='Москва']['cost_per_month']
sample_2=data_total[data_total['city']!='Москва']['cost_per_month']
alpha=0.05 # коэффициент статистической значимости

results=st.ttest_ind(sample_1, sample_2, equal_var=False)
print ('p-значение=',results.pvalue)

if results.pvalue < alpha:
    display('Отвергаем нулевую гипотезу')
else:
    display('Не получилось отвергнуть нулевую гипотезу')

# %% [markdown]
# Как мы видим, несмотря на то,что средние выручки москвичей и региональных абонентов отличаются, они настолько близки по значению, что
# не попадают в коэффициент статистической значимости. А следовательно нельзя опровергнуть нулевую гипотезу, то есть можно утверждать, что выручки равны.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что дополнительно показаны средние выручки, как иллюстрация не противоречивости нашей проверки гипотез. 👍</font>

# %% [markdown]
# ## Общие выводы:
# Исследование показало, что никто из абонентов тарифа Ultra не превышают установленные лимиты ни по времени звонков, ни по количеству смс, ни по расходу интернет траффика. В то время как абоненты Smart часто превышают. Многими услугами абоненты обоих тарифов вообще не пользуются (330 абонентов из выборки Ultra - 0 sms, 210 абонентов Smart - 0 sms, не используют услуги голосовой связи -  50 абонентов из выборки тарифа Ultra, 22 абонента Smart)
# Несмотря на то, что превышение лимитов и доплата за услуги связи случается у абонентов Smart, в целом для компании тариф ULtra выгоднее, так как средняя выручка абонентов этого тарифа составляет 2070.15 в отличие от 1289.97 средней выручки абонентов Smart, что на 62.31% выше. Сопоставительный анализ выручки абонентов из Москвы и из регионов показал, что средние выручки практически равны (1546.71 рублей для Москвы и  1524.93 для регионов), разница настолько мала,что не имеет статистической значимости, что подтверждено статистическим исследованием (p-значение оказалось выше коэффициента статистической значимости).
#
# Что касается прибыльности тарифов,то более прибыльным оказался тариф Smart, за счет большего числа абонентов, лучшей динамики по выручке по итогам года, несмотря на то,что показатель "выручка с абонента" выше в тарифе Ultra.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 ОЙ! У нас была цель исследования и в общих выводах мы должны ее отразить.</font><br>
# <font color='DarkMagenta'>👉 И очень пригодился бы график динамики выручки по месяцам в разрезе тарифов. Есть ли там тренды, выручка по какому-то тарифу растет или падает? Сделаем?</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br><br>
# <font color='DarkGreen'>👌 Сергей, проект очень хорошо и детально проработан. И дальше так держать!<br></font>
# <font color='Red'>🛠 А что бы еще лучше сделать проект нам надо:</font><br>
# <font color='Red'>🛠 Проанализировать пропажу пользователей после объединения таблиц. Необходимо провести анализ выручки в разрезе тарифов. В итоговом выводе должна найти свое отражение цель исследования. <br></font>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов мы приобретем дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Удачи. </font>
