# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет!\
#     Ты хорошо поработал, но осталось еще несколько критических замечаний.
#
# Проведи проверку и высылай проект на ревью! 🙂
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Сергей, привет!
#
# Меня зовут Сергей Кулешин, и я буду делать ревью твоего проекта. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом. Моя основная цель - не указать тебе на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# <div style="background:#e5e5e5; color:#000; padding:10px">
#     <b>Общее впечатление о проекте</b>
#
# Видно, что ты умеешь писать и применять функции, это здорово облегчает работу аналитика. Однако ты не до конца разобрался в причинах убыточности бизнеса.
# </div>

# %% [markdown]
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌  Каждый аналитический проект должен начинаться, например с: Названия, краткого описания проекта, целей и задач, описания исходных данных, плана (декомпозиции) анализа данных и др информации. Добавь пожалуйста.
# </div>

# %% [markdown]
#                   Исследование причин неокупаемости рекламных кампания компании Procrastinate Pro+
#
# Последние несколько месяцев компания Procrastinate Pro+ терпит убытки. Наша задача — разобраться в причинах и помочь компании выйти в плюс.
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# •	лог сервера с данными об их посещениях,
# •	выгрузка их покупок за этот период,
# •	рекламные расходы.
# Нам предстоит изучить:
# •	откуда приходят пользователи и какими устройствами они пользуются,
# •	сколько стоит привлечение пользователей из различных рекламных каналов;
# •	сколько денег приносит каждый клиент,
# •	когда расходы на привлечение клиента окупаются,
# •	какие факторы мешают привлечению клиентов.
#
# В нашем распоряжении три датасета. Файл visits_info_short.csv хранит лог сервера с информацией о посещениях сайта, orders_info_short.csv — информацию о заказах, а costs_info_short.csv — информацию о расходах на рекламу.
# Структура visits_info_short.csv:
# •	User Id — уникальный идентификатор пользователя,
# •	Region — страна пользователя,
# •	Device — тип устройства пользователя,
# •	Channel — идентификатор источника перехода,
# •	Session Start — дата и время начала сессии,
# •	Session End — дата и время окончания сессии.
# Структура orders_info_short.csv:
# •	User Id — уникальный идентификатор пользователя,
# •	Event Dt — дата и время покупки,
# •	Revenue — сумма заказа.
# Структура costs_info_short.csv:
# •	dt — дата проведения рекламной кампании,
# •	Channel — идентификатор рекламного источника,
# •	costs — расходы на эту кампанию.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Описание проекта есть.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Ссылки на скачивание файлов лучше убрать. По правилам Яндекса проекты нельзя выкладывать с прямыми ссылками к данным.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👌
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from scipy import stats as st

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv') # прочитаем датасеты, выведем первые 10 строк дляь изучения содержимого
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv ('/datasets/costs_info_short.csv')
display (visits.head(10))
display (orders.head(10))
display (costs.head(10))
# Out:
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %%
visits.info() # проверим на предмет пропусков и типов данных
orders.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# В результат видим, что пропущенных данных нет, количество строк везде одинаковое. Видем несоответствие типов данных в некоторых столбцах. Приведем данные в порядок приведем названия столбцов к змеиному регистру.

# %%
visits.rename (columns= {'User Id': 'user_id', 'Region':'region', 'Device':'device', 'Channel':'channel',\
                                'Session Start': 'session_start', 'Session End': 'session_end'}, inplace=True)
visits.info()
visits ['session_start'] = pd.to_datetime (visits['session_start']) 
visits ['session_end'] = pd.to_datetime (visits['session_end'])
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
# ...

# %%
# проделаем то же самое с orders  и costs
orders.rename (columns= {'User Id': 'user_id', 'Event Dt':'event_dt', 'Revenue':'revenue'}, inplace=True)
orders.info()
orders ['event_dt'] = pd.to_datetime (orders['event_dt']) 
orders.info()

costs.rename (columns= {'Channel': 'channel'}, inplace=True)
costs.info()
costs ['dt'] = pd.to_datetime (costs['dt']).dt.date 
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
# ...

# %%
# проверим на дубликаты
visits.duplicated().sum()
orders.duplicated().sum()
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Не стоит удалять дубликаты не проверив количество, если их окажется 50% или больше? Значит загружаемые данные не корректны , но мы этого не узнаем и будем дальше с ними работать. Лучше сначала проверить количество дубликатов:
# ```python
#     df.duplicated().sum()
# ```
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   поправил.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Хорошо.
# </div>

# %% [markdown]
# Дубликатов не было.
#  Предобработка данных завершена.
#  Мы привели названия столбцов к нижнему регистру, изменили тип данных, избавились от дубликатов.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Данные получены и подготовлены к анализу! Хорошо, что заметил неверный формат даты и поменял.
# </div>

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %%
def get_profiles(visits, orders, costs):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
def get_retention(profiles, sessions, observation_date, horizon_days, dimensions = [], ignore_horizon = False):
    
    # решаем какие столбцы оставим для группировки удержания, столбец признака платящего пользователя остается всегда
    dimensions = ['payer'] + dimensions
    
    # оттсекаем всех пользователей, которые не могли "дожить" до нужного горизонта 
    # (присоединились позже чем observation_date - horizon)
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # формируем массив сырых данных
    result_raw = result_raw.merge(sessions[['user_id', 'session_start']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days
    
    # функция группировки по нужному набору измерений
    def group_by_dimensions(df, dims, horizon_days):     
        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'user_id', aggfunc = 'nunique')     # строим "треугольную таблицу" 
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'}) # определяем размеры когорт
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)                                   # присоединяем размеры когорт к треугольной таблице
        result = result.div(result['cohort_size'], axis = 0)                                                     # делим каждый из столбцов на размер когорты - расчитываем % удержания (retention rate)
        result = result[['cohort_size'] + list(range(horizon_days))]                                             # оставляем только наблюдения до нужного горизонта и столбец размеров когорт
        result['cohort_size'] = cohort_sizes                                                                     # пересприсваиваем столбец размеров когорт, ведь во время деления он превратился в 1
        return result
    
    # расчитываем удержание 
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    # рассчитываем удержание по всем параметрам + дата
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    # возвращаем и таблицы удержания и сырые данные (чтобы в случае чего можно было в них покопаться при отладке)
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
def plot_retention(retention, retention_history, horizon, window):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержания первого дня
    retention = retention.drop(columns=['cohort_size', 0])

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey = ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные, строим сводную таблицу и график по ней
    retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon-1, aggfunc='mean'
    ).plot(grid=True, ax=ax3)
    filtered_data = retention_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    # в четвёртой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey = ax3)
    # фильтруем данные, строим сводную таблицу и график по ней
    retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    ).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # исключаем наложение графиков друг на друга
    plt.tight_layout()

    plt.show()

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# считаем LTV, CAC и ROI

# строим графики
# plot_ltv_roi(ltv, ltv_history, roi, roi_history, 7)

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Отличные функции!
# </div>

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %%
profiles = get_profiles(visits, orders, costs)
display (profiles.head(10))
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Не выводи на показ весь датафрейм, при больших объемах можно подвесить ноутбук. Используй head(), tail() или sample().
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Поправил.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👌
# </div>

# %%
# определим минимальную и максимальную дату привлечения пользователей
session_min = profiles['first_ts'].dt.date.min()
session_max = profiles['first_ts'].dt.date.max()
print('минимальная дата', session_min)
print('максимальная дата', session_max)
# Out:
# минимальная дата 2019-05-01
# максимальная дата 2019-10-27

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Замечательно, у нас есть даты и они совпадают с заданием!
# </div>

# %%
# изучим пользователей по странам
region_users = profiles.groupby('region').agg({'user_id': 'nunique'})
print (region_users)

plt.figure(figsize=(13,4))
sns.barplot(x=region_users.index,y=region_users['user_id'])
plt.title("Распределение пользователей по странам")
plt.xlabel("Страна")
plt.ylabel("Количество уникальных пользователей")
# Out:
#                user_id
# region
# France           17450
# Germany          14981
# UK               17575
# United States   100002
# Text(0, 0.5, 'Количество уникальных пользователей')

# %%
# изучим пользователей по странам
region_payers = profiles[profiles['payer'] == True].groupby('region').agg({'user_id': 'nunique'})
print (region_payers)

plt.figure(figsize=(13,4))
sns.barplot(x=region_payers.index,y=region_payers['user_id'])
plt.title("Распределение плательщиков по странам")
plt.xlabel("Страна")
plt.ylabel("Количество уникальных плательщиков")
# Out:
#                user_id
# region
# France             663
# Germany            616
# UK                 700
# United States     6902
# Text(0, 0.5, 'Количество уникальных плательщиков')

# %% [markdown]
# Больше всего уникальных плательщиков в США, меньше всего в Германии. Разница с ближайшим конкурентом Великобританией почти в 10 раз. Посмотрим на отношение пользователей к плательщикам.

# %%
region_users['payers'] = region_payers['user_id']
region_users['relation %'] = (region_payers['user_id']/region_users['user_id'] *100).round(2)
region_users
# Out:
#                user_id  payers  relation %
# region
# France           17450     663        3.80
# Germany          14981     616        4.11
# UK               17575     700        3.98
# United States   100002    6902        6.90

# %%
# посчитаем количество пользователей по каждому типу устройств
device_users = profiles.groupby('device').agg({'user_id': 'nunique'})
print (device_users)

plt.figure(figsize=(13,4))
sns.barplot(x=device_users.index,y=device_users['user_id'])
plt.title("Распределение пользователей по устройствам")
plt.xlabel("Устройство")
plt.ylabel("Количество уникальных пользователей")
# Out:
#          user_id
# device
# Android    35032
# Mac        30042
# PC         30455
# iPhone     54479
# Text(0, 0.5, 'Количество уникальных пользователей')

# %%
# посчитаем количество пользователей-плательщиков по каждому типу устройств
device_payers = profiles[profiles['payer'] == True].groupby('device').agg({'user_id': 'nunique'})
print (device_payers)

plt.figure(figsize=(13,4))
sns.barplot(x=device_payers.index,y=device_payers['user_id'])
plt.title("Распределение плательщиков по устройствам")
plt.xlabel("Устройство")
plt.ylabel("Количество уникальных пользователей")
# Out:
#          user_id
# device
# Android     2050
# Mac         1912
# PC          1537
# iPhone      3382
# Text(0, 0.5, 'Количество уникальных пользователей')

# %%
device_users['payers'] = device_payers['user_id']
device_users['relation %'] = (device_payers['user_id']/device_users['user_id'] *100).round(2)
device_users.sort_values(by='user_id')
# Out:
#          user_id  payers  relation %
# device
# Mac        30042    1912        6.36
# PC         30455    1537        5.05
# Android    35032    2050        5.85
# iPhone     54479    3382        6.21

# %% [markdown]
# Анализ пользователей по устройствам показал, что максимальное количество пользователей пользуются iPhone, процент платящих - 6.21%. Наименьшее количество юзеров на Mac, однако доля платящих тут лидирующая - 6.36%. То есть пользователи Mac лучше всех конвертятся в плательщиков. Хуже всего обстоят дела с пользователями PC. По количеству пользователей едва опережает аутсайдера, почти вдвое меньше,чем пользователей с iPhone, и показательконверсии в плательщиков самый низкий - 5.05%

# %%
# посчитаем количество пользователей-плательщиков, пришедших из разных рекламных каналов. Определим лидеров и аутсайдеров
channel_users = profiles.groupby('channel').agg({'user_id': 'nunique'}).sort_values(by ='user_id')
channel_payers = profiles[profiles['payer'] == True].groupby('channel').agg({'user_id': 'nunique'}).\
sort_values(by ='user_id')
print (channel_payers)

plt.figure(figsize=(13,4))
sns.barplot(x=channel_payers.index,y=channel_payers['user_id'])
plt.title("Распределение плательщиков по каналам")
plt.xlabel("Канал")
plt.ylabel("Количество уникальных пользователей")
# Out:
#                     user_id
# channel
# MediaTornado            156
# YRabbit                 165
# lambdaMediaAds          225
# OppleCreativeMedia      233
# LeapBob                 262
# RocketSuperAds          352
# AdNonSense              440
# WahooNetBanner          453
# organic                1160
# TipTop                 1878
# FaceBoom               3557
# Text(0, 0.5, 'Количество уникальных пользователей')

# %%
channel_users['payers'] = channel_payers['user_id']
channel_users['relation %'] = (channel_payers['user_id']/channel_users['user_id'] *100).round(2)
channel_users = channel_users.sort_values(by='relation %', ascending=False)
display(channel_users)
# Out:
#                     user_id  payers  relation %
# channel
# FaceBoom              29144    3557       12.20
# AdNonSense             3880     440       11.34
# lambdaMediaAds         2149     225       10.47
# TipTop                19561    1878        9.60
# RocketSuperAds         4448     352        7.91
# WahooNetBanner         8553     453        5.30
# YRabbit                4312     165        3.83
# MediaTornado           4364     156        3.57
# LeapBob                8553     262        3.06
# OppleCreativeMedia     8605     233        2.71
# organic               56439    1160        2.06

# %%
plt.figure(figsize=(13,4))
sns.barplot(x=channel_users.index,y=channel_users['relation %'])
plt.title("Распределение конверсии по каналам привлечения")
plt.xlabel("Канал")
plt.ylabel("Количество уникальных плательщиков")
# Out:
# Text(0, 0.5, 'Количество уникальных плательщиков')

# %% [markdown]
# Большинство пользователей и клиентов приходят после рекламных кампании на Faceboom и TipTop. Неплохие показатели у органических юзеров, кажется сарафанное радио все еще работает. Однако конверсия органики в клиентот вочти в 6 раз хуже,чем у лидера Faceboom. Хуже всего дела обстоят у канало MedisTornado и Yrabbit- меньше всего юзеров и очень плохая конверсия (3,57 и 3,83%)

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ С платящими определились. Здорово, что добавлена визуализация!
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Вывод доли платящих лучше отсортировать по убыванию этой самой доли.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Поправил
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Отлично! Сортировать всегда лучше по целевой переменной.
# </div>

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %%
display(costs.head(10))
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# 5  2019-05-06  FaceBoom  118.8
# 6  2019-05-07  FaceBoom  101.2
# 7  2019-05-08  FaceBoom  100.1
# 8  2019-05-09  FaceBoom   93.5
# 9  2019-05-10  FaceBoom  104.5

# %%
# посчитаем общую сумму расходов на маркетинг
total_marketing = costs['costs'].sum()
print(total_marketing)
# Out:
# 105497.30000000002

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Общие затраты посчитали.
# </div>

# %%
# посчитаем сколько денег потратили на рекламу с разбивкой по источникам
channel_costs = costs.groupby('channel').agg({'costs':'sum'}).sort_values(by = 'costs', ascending=False)
display(channel_costs)
channel_costs.plot(kind='bar', figsize=(13,4))
plt.title('затраты на рекламу')
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22
# Text(0.5, 1.0, 'затраты на рекламу')

# %%
channel_costs ['relation %'] = (costs.groupby('channel').agg({'costs':'sum'})/channel_costs ['costs'].sum() *100).round(2) #.sort_values(by = 'costs', ascending=False)
display(channel_costs)
# Out:
#                        costs  relation %
# channel
# TipTop              54751.30       51.90
# FaceBoom            32445.60       30.75
# WahooNetBanner       5151.00        4.88
# AdNonSense           3911.25        3.71
# OppleCreativeMedia   2151.25        2.04
# RocketSuperAds       1833.00        1.74
# LeapBob              1797.60        1.70
# lambdaMediaAds       1557.60        1.48
# MediaTornado          954.48        0.90
# YRabbit               944.22        0.90

# %% [markdown]
# На 2 самых популярный канала тратится более 80% общего рекламного бюджета. 51,89% на Tiptop и 30,75% на Faceboom. Посмотрим насколько эффективны такие траты.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️  На популярные каналы тратится больше.
#
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Лучше написать небольшой вывод по полученной табличке.
#
#   ⚠️ Стоит вывести еще процент затрат каждого канала от общей суммы, так будет понятней общая картина.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Сделал
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Замечательно! Видим, что два канала съели более 80% бюджета.
# </div>

# %%
# Построим визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику.
 
costs ['week'] = pd.to_datetime(costs['dt']).dt.isocalendar().week
costs ['month'] = pd.to_datetime(costs['dt']).dt.month
week_channel_costs = costs.groupby(['channel', 'week']).agg({'costs':'sum'}).sort_values(by = 'channel', ascending=True)
month_channel_costs = costs.groupby(['channel', 'month']).agg({'costs':'sum'}).sort_values(by = 'channel', ascending=True)

channel = costs ['channel'].unique()
plt.figure(figsize = (15,10))
plt.subplot (2,1,1)
for i in channel:
    cost_week = costs[costs['channel'] == i].pivot_table (index ='week', values = 'costs', aggfunc = 'sum')
    plt.plot(cost_week, label= i)
plt.legend()
plt.title('маркетинговые траты по неделям')
plt.show()


plt.figure(figsize = (15,10))
plt.subplot (2,1,2)
for i in channel:
    cost_month = costs[costs['channel'] == i].pivot_table (index ='month', values = 'costs', aggfunc = 'sum')
    plt.plot(cost_month, label= i)
plt.legend(loc= 'upper left')
plt.title('маркетинговые траты по месяцам')
plt.show()

    
display(week_channel_costs)
display(month_channel_costs)
# Out:
#                       costs
# channel        week
# AdNonSense     18    211.05
#                43    154.35
#                42    118.65
#                41    136.50
#                40    155.40
# ...                     ...
# lambdaMediaAds 19    103.20
#                18     81.60
#                42     47.20
#                29     41.60
#                43     53.60
#
# [260 rows x 1 columns]
#                               costs
# channel            month
# AdNonSense         5       1169.700
#                    6        538.650
#                    7        504.000
#                    8        579.600
#                    9        581.700
#                    10       537.600
# FaceBoom           5       3524.400
#                    6       5501.100
#                    7       5294.300
#                    8       6274.400
#                    9       6114.900
#                    10      5736.500
# LeapBob            10       315.420
# ...

# %% [markdown]
# На графиках маректинговых расходов наблюдаем плавное, но сильное увеличение затрат на рекламные кампании в Tiptop и Faceboom.
# Расходы на остальные каналы остаются неизменны. Tiptop с 3000 до 13000/мес, и Faceboom с 3500 до 6000/мес.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Видим динамику расходов.
# </div>
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Какие выводы мы можем сделать из графиков?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Выводы по графикам добавил
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👍
# </div>

# %%
profiles = get_profiles(visits, orders, costs)

profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Зачем мы еще раз задаем функцию get_profiles() и создаем профили пользователей?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Дублирующую функцию get_profiles() убрал
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Хорошо.
# </div>

# %%
# Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. 
profiles_filtered= profiles.loc[profiles['channel'] != 'organic']

cac= profiles_filtered.groupby('channel').agg({'acquisition_cost': 'mean'}).round(2).sort_values(by='acquisition_cost')
cac.rename(columns={'acquisition_cost':'cac'}, inplace=True)
cac
# Out:
#                      cac
# channel
# LeapBob             0.21
# MediaTornado        0.22
# YRabbit             0.22
# OppleCreativeMedia  0.25
# RocketSuperAds      0.41
# WahooNetBanner      0.60
# lambdaMediaAds      0.72
# AdNonSense          1.01
# FaceBoom            1.11
# TipTop              2.80

# %%
cac.plot(kind='bar', figsize=(13,4))
plt.title('затраты на рекламу')
# Out:
# Text(0.5, 1.0, 'затраты на рекламу')

# %% [markdown]
# Самый дешевый трафик из канала LeapBob. Стоимость привлечения платящего клиента равно 0,21. Самый высокий САС по каналу TipTop = 2.8$. Посмотрим, окупаются ли инвестиции в рекламу.

# %%
# рассчитаем и добавим в таблицу средний САС по всему проекту и сравним его с CAC по каждому каналу в отдельности.
cac['cac_general'] = profiles_filtered['acquisition_cost'].mean().round(2)
cac
# Out:
#                      cac  cac_general
# channel
# LeapBob             0.21         1.13
# MediaTornado        0.22         1.13
# YRabbit             0.22         1.13
# OppleCreativeMedia  0.25         1.13
# RocketSuperAds      0.41         1.13
# WahooNetBanner      0.60         1.13
# lambdaMediaAds      0.72         1.13
# AdNonSense          1.01         1.13
# FaceBoom            1.11         1.13
# TipTop              2.80         1.13

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ И обходятся популярные каналы дороже.
#
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Можно еще рассчитать средний CAC на одного пользователя для всего проекта, так увидим на сколько выше среднего САС у популярных каналов.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Рассчитал средний САС по проекту и добавил в таблицу для наглядности сравнения
# </div>
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ❌ Что-то у нас САС по каналам поплыл. Не надо учлоднять расчеты, тут лучше просто взять среднее расходов `acquisition_cost` по всем каналам, кроме organic, из датафрейма профилей пользователей `profiles`.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента V.2</b>
#
#   Перессчитал САС по каналам, а также добавил в таблицу средний САС по проекту для наглядности сравнения
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Наиболее дорогостоящим каналом привлечения пользователей является TipTop, однако количество и доля платящих пользователей, приходящих с этого источника, не так высоки. Это можно объяснить молодой аудиторией TipTop'a и, соответственно, не очень высокой их платежеспособностью.
#
# </div>

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %%
# Выведем таблицу с профилями пользователей, отфильтрованную без канала organic
profiles= profiles.loc[profiles['channel'] != 'organic']
profiles.head(10)
# Out:
#       user_id            first_ts         channel   device         region  \
# 0      599326 2019-05-07 20:58:57        FaceBoom      Mac  United States
# 1     4919697 2019-07-09 12:46:07        FaceBoom   iPhone  United States
# 3    22593348 2019-08-22 21:35:48      AdNonSense       PC        Germany
# 4    31989216 2019-10-02 00:07:44         YRabbit   iPhone  United States
# 7    46006712 2019-06-30 03:46:29      AdNonSense  Android         France
# 8    58263264 2019-05-11 19:18:43        FaceBoom   iPhone  United States
# 9    59835779 2019-05-11 21:13:47    MediaTornado   iPhone  United States
# 12   69985732 2019-10-09 21:36:33  RocketSuperAds      Mac  United States
# 17   93828625 2019-07-24 05:56:22         LeapBob   iPhone        Germany
# 19  112595447 2019-08-04 06:39:43          TipTop   iPhone  United States
#
#             dt      month  payer  acquisition_cost
# 0   2019-05-07 2019-05-01   True          1.088172
# 1   2019-07-09 2019-07-01  False          1.107237
# ...

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать такие выводы:
# Реклама не окупается. ROI в конце второй недели приближается к 100%, но все же не доходит до точки окупаемости.
# CAC стабильно растет.
# На LTV влияет сезонный фактор, но и этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
# Чтобы разобраться в причинах, пройдём по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения.

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Тут есть один недочет, который искажает общие данные: из расчетов нам следует исключить пользователей с органическим трафиком, поскольку мы за них ничего не платим. Всю оценку окупаемости рекламы для привлечения пользователей, рассчитываем по пользователям, пришедшим с платныx рекламныx каналов.
#
# Пересчитай все, пожалуйста! Посмотрим, насколько сильно изменятся графики. И подкорректируй выводы.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#  Странно, что исчез этот код. Я изначально удалял канал organic из профайлов. Продублировал.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Хорошо, "бесплатные" пользователи сильно искажают показатели. Поэтому их надо обязательно убирать.
# </div>

# %%
# смотрим конверсию 
dimensions = []
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions,
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия стабильно растет с каждым лайфтаймом, однако конверсия 14го дня очень нестабильна. Возможно дело в удержании, посмотрим на него.

# %%
# смотрим конверсию c разбивкоу по странам
dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions,
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %% [markdown]
# Конверсия европейских пользователей просаживается в июле и сентябре. Возможно фактор сезонности.Хорошие показатели у всех европейцев в конце мая, Немцы хорошо конвертились в конце июля, с показателем 6% и концу сентября-начале октября, с показателем 6,5%. В начале сентября хороший скачек до 7% показали пользователи из Великобритании, однако с этого времени конверсия неуклонно снижается. Возможно дело в удержании. Французы более стабильны, наблюдаются 3 просадки до показателей в 3,5% в конце июня, июля и августа, но с сентября резкий скачок до 6% и плавное падение до 5%.
# США - явный лидер конверсии, с конца мая наблюдаем рост с 8% до 11% к середине июня, затем выравнивается к 10% к концу октября.

# %%
# смотрим конверсию c разбивкоу по рекламным каналам
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions,
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=25)

# %% [markdown]
# Самую высокую конверсию показывают каналы Faceboom и Nonsense, на уровне 10,5 и 12%. Чуть хуже идут каналы LambdaMediaAds и
# Tiptop c 10,2 и 9,3%. Самая низкая конверсия у каналов OppleCreativeMedia, LeapBob, Mediatornado и Yrabbit.
# Самая нестабильная динамика у lembdaMediaAds и Adnonsense,которая достигает 12-12% к концу октября.

# %%
# Рассчитаем САС. 
# добавляем параметр ad_costs — траты на рекламу
def get_profiles(sessions, orders, ad_costs):

    # сортируем сессии по ID пользователя и дате привлечения
    # группируем по ID и находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
         # время первого посещения назовём first_ts
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()  # возвращаем user_id из индекса
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = pd.to_datetime(profiles['dt'], format ='%Y-%m-%d')
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
         # столбец с числом пользователей назовём unique_users
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()  # возвращаем dt и channel из индексов
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    # по дате и каналу привлечения
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    # результаты сохраним в столбец acquisition_cost (CAC)
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавим стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # органические пользователи не связаны с данными о рекламе,
    # поэтому в столбце acquisition_cost у них значения NaN
    # заменим их на ноль, ведь стоимость привлечения равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles  # возвращаем профили с CAC

# %% [markdown]
# По рекламным каналам картина следующая:
# Faceboom - лидер коверсии.На 14й лайфтайм плательщиками становятся 12 человек из 100.Динамика положительная, с середины августа рост. Резких падений нет.
# Еще один лидер конверсии, канал AdNonsense: конверсия 14го лайфтайма около 11%, динамика одна из самый высоких, к началу октября становится лидером с пиковым показателем в 14%.
# Среди аутсаедеров: WahooNetBanner,LeapBob, Media Tornado и YRabbit. Эти каналы приводят максимум 5 клиентов из 100 пользователей.

# %%
# смотрим конверсию c разбивкоу по устройствам
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions,
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=25)

# %% [markdown]
# Конверсия по устройствам:
#     Среди лидеров iPhone и Mac, с показателями 8,5 и 8,7% на 14й лайфтайм соответственно. График динамики нам показывает примерно одинаковую конверсию на всех устройствах в начале проекта, но со временем, кривый Mac и iPhone идут вврех, У Mac
# временами пробивая 9 и даже 9,5%.
# Android тоже не отстает от лидеров, даже иногда показывая лучшие результаты. Средние значения около 8%.
# Хуже всех дела обстоят с конверсией пользователей РС. Динамика нисходящая, с конца июля отыграл почти 1,5%, с 5,5 до 7, но затем крива снова идет вниз. Возможно причина в плохом удержании или маленьких бюджетах на рекламу для пользователей РС.

# %%
# смотрим удержание

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, window=20)

# %%
# смотрим удержание по странам
dimensions=['region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, window=30)

# %% [markdown]
# Удержание по странам:
#     США - плавно падает с 0,36 до 0,9 на 14Й лайфтайм.
#     Европейские страны - картина немного "веселее". Удержание чуть выше, динамика скачкообразная.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Еще одну проблему в США обнаружили.
# </div>

# %%
# смотрим удержание по каналам
dimensions=['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, window=40)

# %% [markdown]
# Удержание сильно падает, удержание 14го дня очень нестабильно. Самое плохое уджеражfние по платящим пользователям на 13лайфтайм:
# - Faceboom
# - Adnonsense
#
# Следом в антирейтинге по удержанию идут каналы:
#
# - Yrabbit (падение с 0.56 до 0.1)
# - MediaTornado (падение с 0.5 до 0.12)
#
# В лидерах по удержанию:
#
# - Wahoo (0.55-0.23)
# - Rocketsuperads (0.57-0.23)
#
# Динамика удержания неплатящих пользователей наоборот стабильно около 0.

# %% [markdown]
# <div class="alert alert-danger">
#   <b>Комментарий ревьюера v.2</b>
#
#
#   ❌ Удержание падает по каким каналам?
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента V.2 </b>
#
#  Комментарии по графикам удержания добавил.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Хорошо, анализ  удержания корректен, согласен с интерпретацией результатов. Проблемные источники определены верно.

# %% [markdown]
# •	Проанализируем окупаемость рекламы с разбивкой по устройствам. Для этого построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
dimensions = ['device']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=15)

# %% [markdown]
# По устройствам наблюдаем следующую картину:
# - LTV самый высокий у пользователей iPhone и Mac, чуть ниже у Android, самый низкий у PC
# - Однако пользователи PC окупаются быстрее всех, уже на 8 день, следом идут пользователи Android. Mac и iPhone на 14 день не окупаются.
# - Кроме того, самая низкая стоимость клиента на 14 день у пользователей PC (около 0,62), чуть выше у Android. самыми дорогими клиентами становятся пользователи Mac и iPhone с показателями около 1. Также у них наблюдается резкий рост САС начиная с июня. Возможно фактор сезонности.

# %%
# посмотрим на показатели с разбивкой по странам
dimensions = ['region']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %%
# посмотрим на показатели с разбивкой по каналам
dimensions = ['channel']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Анализ CAC, ROI, LTV и их динамики показал нам очевидную проблему. Пользователи из США. Они не окупаются, в отличии от европейцев. Очень тревожный показатель САС по американцам. Он реско вырастает в июне и становится безумно высоким с осени,колебляст вокруг 1,1, в то время когда стоимость привлечения пользователей из Европы стабильна, в районе 0,3$ без резких скачков. На графике динамики ROI мы наблюдаем провал наже уровня ркупаемости уже в начале июне, видимо это связано с резком росто стоимости привлечения клиента, и стабильный уход в минус со второй половины июня. Даже несмотря на самый высокий LTV и стабильную динамику LTV, американцы не окупаются.

# %%
profiles_usa = profiles.loc[profiles['region'] == 'United States']
dimensions=[]
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_usa, orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=15)

# %%
# смотрим удержание по США
dimensions=[]
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_usa, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, window=30)

# %%
# посмотрим на конверсию в США
dimensions = []
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_usa, orders, observation_date, horizon_days, dimensions = dimensions,
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=25)

# %% [markdown]
# Подробнее посмотрели на графики по США:
#     LTV растет, САС резко растет, удержание пользователей сильно падает, конверсия неплохая, динамика конверсии восходящая.
#     ROI очень низкий на уровне 0,7, до окупаемости далеко. Динамика ROI нисходящая, шансов на окупаемость почти нет.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ "втовремякогдастоимостьпривлеченияпользователейизЕвропыстабильна,врайоне0,3" ?
#
#   ⚠️ Согласен, можно еще изучить рекламу в США отдельно.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#  Ошибку написания в маркдаун исправил. Видимо так повлиял значок доллара. Почему, еще не гуглил.
#     Рекламу по каналам/девайсам/конверсии/удержанию/LTV/Roi/динамике изучил. Выводы сделал.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Тут лучше создать отдельный датафрейм только пользователей по США и дальше по этому датафрейму построить графики из текущего шага с разбивкой по каналам и устройствам. Европу можно аналогично рассмотреть.
# </div>

# %%
# посмотрим на показатели с разбивкой по каналам привлечения
dimensions = ['channel']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=30)

# %% [markdown]
# Самые высокие показатели LTV у каналов LambdaMediaAds и Tiptop - 1.75 и 1.5 соответственно.
# У Tiptop динамика стабильно высокая, без резких колебаний.
# У канала LambdaMedisAds более волатильна, но к концу октября сильно отрывается от конкурентов.
# CAC у канала Tiptop сильно вырастает с мая по октябрь, в то время как у остальных каналов остается практически неизменным.
# Не окупаются всего 3 канала: Tiptop, Faceboom и Adnonsense.
# По графику динамики Roi видно,что OppleCreativeMedia очень рисковый канал,так как его Roi ближе всего к отметка самоокупаемости. А вот канал Yrabbit демонстрирует какое-то маркетинговое чудо, взлетая к середине июля до 5,3, правда к октябрю опускается до 3, что все равно очень неплохой показатель "в рынке".

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Какие выводы можем сделать из графиков по каналам? После каждого построение графиков пишем выводы по ним, не стоит заставлять заказчика самостоятельно придумывать.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Выводы после графиков добавил.
# </div>
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ❌ Третий не окупающийся канал у нас не Leapbob, проверь еще раз график.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента V.2</b>
#
#   Перепутал цвет на графике. Грубая ошибка- неправильный вывод. Согласен. Спасибо,что обратил моё внимание.Поправил
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Здорово, что разобрались)

# %% [markdown]
# Количество платящих пользователей(клиентов) из США почти в 10 раз превышает количество пользователей из любой другой страны.
# Количество пользователей из Великобритании, Германии и Франции находится в диапазоне от 616 до 700.
# Также пользователи США лучше конвертятся в плательщиков. Примерно 6,9% юзеров становится клиентами,
# в то время как европейцы конвертятся хуже (3,8-4,1%).
# По типу устройств большинство клиентов пользуются iPhone, на втором месте Android, затем Mac и PC.
# Конверсия юзеров в клиентов лучше на устройствах Mac и iPhone, но разница не критична: 6,36 и 6,21% против 5,85 и 5,05% у Android и PC соответственно.
#
# Большинство пользователей и клиентов приходят после рекламных кампании на Faceboom и TipTop.
# Неплохие показатели у органических юзеров, кажется сарафанное радио все еще работает. Однако конверсия органики в клиентот вочти в 6 раз хуже,чем у лидера Faceboom.
# Хуже всего дела обстоят у канало MedisTornado и Yrabbit- меньше всего юзеров и очень плохая конверсия (3,57 и 3,83%)
#
# Судя по графику динамики расходов на маркетинг, компания сделала ставку на 2 канала продвижения: Faceboom и Tiptop,
# увеличив расходы на кампании в этих каналах в 6 и в 3 раза соотвтетственно.
# Расходы на остальные каналы остались на уровне майских показателей.
#
# По графикам можно сделать такие выводы: Реклама не окупается. ROI в конце недели приближается к 100%, но все же не доходит до нее.
# CAC растет.
# Конверсия на 14й день растет, но очень не6стабильна. Удержание клиентов падает с 0,41 в первый лайфтайм до 0,14 на 14Й.
# Несмотря на лидерские позиции пользователей из Америки по количеству клиентов и конверсии, они единственные не окупаются.
# Вероятнее всего причиной этого является безумно высокая стоимость привлечения клиента в США, что подтверждается графиком CAC по типу устройств.
# Стоимость привлечения пользователей iPhone и Mac сильно вырастает с мая, ведь именно эти устройства предпочитают американцы.
# На графике ROI по устройствам,мы видим, что пользователи этих устройств не окупаются.
# Динамика ROI 14ого лайфтайма по этим устройствам нисходящая.
# Анлиз каналов привлечения показал резкий рост САС с 1,4 до 3,6 только из  Tiptop, несмотря на высокий LTV этого канала и стабильную динамику 14го лайфтайма.
# Стоимость привлечения из других каналов стабильно низкая (от 0,3 до 1,1).

# %% [markdown]
# <div class="alert alert-danger">
#   <b>Комментарий ревьюера</b>
#
#
#   ❌ Не хватает анализа и графиков конверсии и удержания пользователей по странам\каналам\устройствам. Без них наш анализ получается не полный, т.к. проблемы могут быть и в удержании, а без анализа конверсии мы не сможем дать рекомендации отделу маркетинга.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Недостающие графики добавил.
# </div>

# %% [markdown]
# ### Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# Вывод:
# Основная причина плохой окупаемости рекламы по проекту:
# США - при высоком LTV и наибольшем количестве клиентов,а также наилучшей конверсией, пользователи из США не окупаются. Стоимость привлечения самая дорогая (САС =   ) Удержание клиентов из США самое плохое - плавно падает с 0,36 до 0,09 на 14Й лайфтайм.Таким образом клиенты из США, хоть и являются довольно качественными, все же убыточны из-за высокого САС, плохого удержания и слишком больших трат на рекламу в США. Вероятно одной из причин неокупаемости американцев является их предпочтение к устройствам iPhone и Mac, а также популярным в США соцсетям Faceboom и TipTop.
#
# Пользователи iPhone и Mac стабильно не окупаются! Все также высокий LTV (),не проблема в том,что очень высокий CAC (15 долларов), восходящая динамика САС по месяцам, вероятно и дальше будет расти. Динамика ROI нисходящая, то есть реклама на этих устройствах уже убыточна и в ближайшей перспективе этот тренд не изменится.
#
# Среди каналов проблемными являются Tiptop, Faceboom и ADNonsense, которые не окупаются. У Faceboom и Adnonsense стабильно низкий LTV (0.5-0.8). Удержание плательщиков на этих каналах на 13й лайфтайм приближается к 0. САС этих каналов один из самых высоких: 1.11-Faceboom и 1.01-Adnonsense. На привлечение пользователей из неокупаемого канала Faceboom тратится 30.75% рекламного бюджета компании, и динамика расходов за последние 6 месяцев увеличивается, что явно тянет общую эффективность компании вниз, даже несмотря на неплохую конверсию канала и максимальное количество привлеченных пользователей (более 3500). Самые "тяжелые" для рекламного бюджета каналы это Tiptop и Faceboom, так как на них тратится больше всего рекламного бюджета.  Оба канала не окупаются. Отдельного внимания заслуживает канал TipTop: при достаточно хорошем LTV, неплохих показателя удержания, хорошей конверсии, этот канал все же является убыточным, так как CAC составляет 2.8, что почть в 2.5 раза выше среднего САС по проекту. Чрезмерно высокая стоимость привллечения пользователей с канала и огромные траты на маркетинг в этом канале, делают компании на Tiptop неэффективными и неокупаемыми. Самую высокую конверсию показывают каналы Faceboom и Nonsense, на уровне 10,5 и 12%. Чуть хуже идут каналы LambdaMediaAds и
# Tiptop c 10,2 и 9,3%. Самая низкая конверсия у каналов OppleCreativeMedia, LeapBob, Mediatornado и Yrabbit.
# Самая нестабильная динамика у lembdaMediaAds и Adnonsense,которая достигает 12-12% к концу октября. Удержание
# Огромной проблемой является резкое повышение стоимости рекламы в Tiptop (САС=3,6 проти 1,1 в мае), что даже при высокой LTV в 1,5 на 14й лайфтайм, делает его нерентабельным. Динамика ROI стабильно ничже уровня окупаемости без восходящик трендов.
#
#
# Отделу маркетинга следует обратить внимание на привлечение аудитории из США, пользователей iPhone и Mac, которые стабильно не окупаются из-за высокой стоимости привлечения клиента. А также пересмотреть стратегию размещения и бюджеты на рекламные кампании в каналах Tiptop, Faceboom и Nonsense, которые также не окупаются и приносят убытки.
# Маркетологам стоит обратить больше внимания на канал LambdaMedia, у которого самый высокий LTV, низкий CAC, неплохая динамика ROI 14го дня в диапазоне 2-3 (не маркетинговое чудо, но в целом уверенно хороший показатель окупаемости). Динамика LTV  могла бы быть стабильнее, но в целом держится на отметках 1,3-2,3, что вполне неплохо при стоимость клиента в 0,75.
# А также к каналам Yrabbit с окупаемостью уже в первый лайфтайм, одной из лучших динамик ROI, низким CAC = 0.2. Конверсия и удеражание по каналу составляют  0,3-0,5% и 0,1%, но это поправимо.
#
# По региональному сегменту, маркетологами следует обратить внимание на пользователей из Великобритании. Хоть у них LTV и ниже, чем у американцев, зато они быстрее всех окупаются (уже на второй лайфтайм), показывают неплохую динамику ROI на 14й лайфтайм при низкой стоимости клиента в районе 0,3 доллара.
# С точки зрения устройства, наиболее перспективно смотрится PC. LTV пользователей не намного ниже LTV других устройств, зато окупаемость самая быстрая, на 7й лайфтайм. Кроме того у PC самая низкая стоимость привлечения клиента, и неплохая динамика ROI на 14й лайфтайм, практически всегда над линией окупаемости.

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ В этом проекте очень важно дать интерпретацию графикам и написать развернутые выводы.
# Нам надо найти и указать причины плохой окупаемости рекламы:
# - реклама в США - проблемы такие-то
# - канал TipTop - увеличение САС
# - канал FaceBoom, AdNonSense - проблемы с ..?\
# и т.д.
#
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ В рекомендации стоит добавить еще несколько перспективных каналов, в идеале с привязкой к регионам (США и Европа). У нас точно окупается больше одного канала. Маркетологи оценят! 🙂
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Общие выводы сделал более понятными и конкретными.
# </div>
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ❌ В выводе так и не видим причин не окупаемости каналов FaceBoom и AdNonSense.
#
#
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента V.2 </b>
#
#   Добавил информацию о причинах неокупаемости каналов Faceboom и Adnonsense. Отдельно расписал по каналу Tip top.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Отличные рекомендации для отдела маркетинга)

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#   <b>Чек-лист доработок</b>
#
#   📃 Добавить краткое описание проекта.
#
#   📃 Убрать канал "organic" из анализа причин неудовлетворительной окупаемости рекламных затрат.
#
#   📃 Написать выводы по всем графикам в шаге анализа причин неудовлетворительной окупаемости рекламных затрат.
#
#   📃 Проанализировать конверсию и удержание пользователей по странам\каналам\устройствам.
#
#   📃 Пересмотреть общий вывод, добавить больше конкретики.
#
#
# Жду твой проект на повторное ревью. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится.
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок v.2</b>
#
#   📃 Проверить расчеты CAC по каждому источнику.
#
#   📃 Проверить выводы по графикам в шаге анализа причин неудовлетворительной окупаемости рекламных затрат.
#
#   📃 Написать более развернутый общий вывод.
#
# Исправляй и присылай проект на ревью.
# </div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №3__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
